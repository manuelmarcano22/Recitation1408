# %% [markdown]
# # Physics 1408 Recitation
#
# ## Manuel Pichardo Marcano
# - manuel.pichardo-marcano@ttu.edu

# %%
from sympy import *
from sympy.utilities.lambdify import lambdify
t = Symbol('t')
from IPython.display import Image


import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

#Velocity
funcv1 = - 2*t + 2
funcv2 = 2*t - 6
funv = Piecewise( (funcv1, t<2), (funcv2, t>=2))
evalfunc = lambdify(t, funv, modules=['numpy'])

#Position
funpos = funv.integrate()
evalfuncpos = lambdify(t,funpos, modules=['numpy'])

#Acceleration
evalfuncacc = lambdify(t,funv.diff(), modules=['numpy'])

t = np.linspace(0, 3.0, 100)
#Figure
width = 12
height = 12
fig = plt.figure(figsize=(width, height))
ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.xlabel('t')
plt.ylabel('V')


plt.plot(t, evalfunc(t), 'b')
plt.show()

# %%
fig

# %%
s1 = evalfuncpos(t)
s2 = evalfunc(t)
s3 = evalfuncacc(t)

width = 12
height = 12
fig = plt.figure(figsize=(width, height))

ax1 = plt.subplot(311)
plt.plot(t, s1)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax1.get_yticklabels(), visible=False)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax1.spines['left'].set_position('zero')
ax1.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.set_ylim(-10,5)
plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.xlabel('t')
plt.ylabel('x')

# share x only
ax2 = plt.subplot(312, sharex=ax1)
plt.plot(t, s2)
# make these tick labels invisible
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=False)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax2.spines['left'].set_position('zero')
ax2.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax2.spines['right'].set_color('none')
ax2.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.set_ylim(-2, 2.0)
plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.ylabel('V')

# share x and y
ax3 = plt.subplot(313, sharex=ax1)
plt.plot(t, s3)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax3.spines['left'].set_position('zero')
ax3.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.set_ylim(-2, 2.0)
plt.ylabel('a')

plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.show()

# %%
fig

# %% [markdown]
# ## Increase the time

# %%
t = np.linspace(0, 10.0, 100)
s1 = evalfuncpos(t)
s2 = evalfunc(t)
s3 = evalfuncacc(t)

width = 12
height = 12
fig = plt.figure(figsize=(width, height))

ax1 = plt.subplot(311)
plt.plot(t, s1)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax1.get_yticklabels(), visible=False)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax1.spines['left'].set_position('zero')
ax1.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.set_ylim(-10,5)
plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.xlabel('t')
plt.ylabel('x')

# share x only
ax2 = plt.subplot(312, sharex=ax1)
plt.plot(t, s2)
# make these tick labels invisible
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=False)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax2.spines['left'].set_position('zero')
ax2.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax2.spines['right'].set_color('none')
ax2.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.set_ylim(-2, 2.0)
plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.ylabel('V')

# share x and y
ax3 = plt.subplot(313, sharex=ax1)
plt.plot(t, s3)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax3.spines['left'].set_position('zero')
ax3.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.set_ylim(-2, 2.0)
plt.ylabel('a')

plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.show()

# %%
fig

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
from matplotlib import animation, rc
rc('animation', html='html5')


t = np.linspace(0, 10.0, 1000)
#------------------------------------------------------------
# set up figure and animation
fig = plt.figure()
ax = fig.add_subplot(111, aspect='equal', autoscale_on=False,
                     xlim=(-10,50), ylim=(-1, 1))
ax.grid()

line, = ax.plot([], [], 'o-', lw=2)
time_text = ax.text(0.02, 0.95, '', transform=ax.transAxes)

def init():
    """initialize animation"""
    line.set_data([], [])
    time_text.set_text('')
    ii = 0
    return line, time_text

def animate(i):
    """perform animation step"""
    global  dt
    ii = i + 1
    x =(evalfuncpos(t[ii])  , 0  )   
    line.set_data(x)
    time_text.set_text('time = %.1f' % t[ii])
    return line, time_text

# choose the interval based on dt and the time to animate one step
from time import time
t0 = time()
animate(0)
t1 = time()
dt = t[1]
interval = 1000 * dt - (t1 - t0)
frames = len(t)-1

ani = animation.FuncAnimation(fig, animate, frames=frames,
                              interval=interval, blit=True, init_func=init)
# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is

# %%
ani

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
from matplotlib import animation, rc
rc('animation', html='html5')


#Velocity
t = Symbol('t')
funcv1 = - 2*t + 2
funcv2 = 2*t - 6
funv = Piecewise( (funcv1, t<2), (funcv2, t>=2))
evalfunc = lambdify(t, funv, modules=['numpy'])

#Position
funpos = funv.integrate()
evalfuncpos = lambdify(t,funpos, modules=['numpy'])

#Acceleration
evalfuncacc = lambdify(t,funv.diff(), modules=['numpy'])
t = np.linspace(0,30.0, 3000)

T = 10
timee = 3 * T
slow_motion_factor = 1
fps = 50
interval = 1 / fps

#------------------------------------------------------------
# set up figure and animation
fig = plt.figure()
ax = fig.add_subplot(111, aspect='equal', autoscale_on=False,
                     xlim=(-10,20), ylim=(-1, 1))
ax.grid()

line, = ax.plot([], [], 'o-', lw=2)
time_text = ax.text(0.02, 0.95, '', transform=ax.transAxes)

def init():
    """initialize animation"""
    line.set_data([], [])
    time_text.set_text('')
    ii = 0
    return line, time_text

def animate(i):
    """perform animation step"""
    global  dt
    ii = i + 1
    x =(evalfuncpos(t[ii])  , 0  )   
    line.set_data(x)
    time_text.set_text('time = %.1f' % t[ii])
    return line, time_text

# choose the interval based on dt and the time to animate one step
from time import time
t0 = time()
animate(0)
t1 = time()
dt = t[1]
#interval = 1000 * dt - (t1 - t0)
interval = 10
frames = len(t)-1

ani = animation.FuncAnimation(fig, animate, frames=frames,
                              interval=interval, blit=True, init_func=init)
# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is

# %%
ani
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-466e978e6b91> in <module>()
# ----> 1 ani
#
# /usr/lib/python3.5/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     244             self.start_displayhook()
#     245             self.write_output_prompt()
# --> 246             format_dict, md_dict = self.compute_format_data(result)
#     247             self.update_user_ns(result)
#     248             self.fill_exec_result(result)
#
# /usr/lib/python3.5/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     148
#     149         """
# --> 150         return self.shell.display_formatter.format(result)
#     151
#     152     # This can be set to True by the write_output_prompt method in a subclass
#
# /usr/lib/python3.5/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     143             md = None
#     144             try:
# --> 145                 data = formatter(obj)
#     146             except:
#     147                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /usr/lib/python3.5/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     188     """show traceback on failed format call"""
#     189     try:
# --> 190         r = method(self, *args, **kwargs)
#     191     except NotImplementedError:
#     192         # don't warn on NotImplementedErrors
#
# /usr/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# /usr/lib/python3.5/site-packages/matplotlib/animation.py in _repr_html_(self)
#    1007         fmt = rcParams['animation.html']
#    1008         if fmt == 'html5':
# -> 1009             return self.to_html5_video()
#    1010
#    1011
#
# /usr/lib/python3.5/site-packages/matplotlib/animation.py in to_html5_video(self)
#     981                                 bitrate=rcParams['animation.bitrate'],
#     982                                 fps=1000. / self._interval)
# --> 983                 self.save(f.name, writer=writer)
#     984
#     985             # Now open and base64 encode
#
# /usr/lib/python3.5/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#     836                         # TODO: See if turning off blit is really necessary
#     837                         anim._draw_next_frame(d, blit=False)
# --> 838                     writer.grab_frame(**savefig_kwargs)
#     839
#     840         # Reconnect signal for first draw if necessary
#
# /usr/lib/python3.5/site-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
#     234             # frame format and dpi.
#     235             self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 236                              dpi=self.dpi, **savefig_kwargs)
#     237         except (RuntimeError, IOError) as e:
#     238             out, err = self._proc.communicate()
#
# /usr/lib/python3.5/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1561             self.set_frameon(frameon)
#    1562
# -> 1563         self.canvas.print_figure(*args, **kwargs)
#    1564
#    1565         if frameon:
#
# /usr/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2230                 orientation=orientation,
#    2231                 bbox_inches_restore=_bbox_inches_restore,
# -> 2232                 **kwargs)
#    2233         finally:
#    2234             if bbox_inches and restore_bbox:
#
# /usr/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_raw(self, filename_or_obj, *args, **kwargs)
#     506
#     507     def print_raw(self, filename_or_obj, *args, **kwargs):
# --> 508         FigureCanvasAgg.draw(self)
#     509         renderer = self.get_renderer()
#     510         original_dpi = renderer.dpi
#
# /usr/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# /usr/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# /usr/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /usr/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# /usr/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2317
#    2318         for zorder, a in dsu:
# -> 2319             a.draw(renderer)
#    2320
#    2321         renderer.close_group('axes')
#
# /usr/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# /usr/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1111
#    1112         for tick in ticks_to_draw:
# -> 1113             tick.draw(renderer)
#    1114
#    1115         # scale up the axis label box to also find the neighbors, not
#
# /usr/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# /usr/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer)
#     249                 self.tick1line.draw(renderer)
#     250             if self.tick2On:
# --> 251                 self.tick2line.draw(renderer)
#     252
#     253             if self.label1On:
#
# /usr/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# /usr/lib/python3.5/site-packages/matplotlib/lines.py in draw(self, renderer)
#     792
#     793             marker = self._marker
# --> 794             tpath, affine = transf_path.get_transformed_points_and_affine()
#     795             if len(tpath.vertices):
#     796                 # subsample the markers if markevery is not None
#
# /usr/lib/python3.5/site-packages/matplotlib/transforms.py in get_transformed_points_and_affine(self)
#    2701         """
#    2702         self._revalidate()
# -> 2703         return self._transformed_points, self.get_affine()
#    2704
#    2705     def get_transformed_path_and_affine(self):
#
# /usr/lib/python3.5/site-packages/matplotlib/transforms.py in get_affine(self)
#    2720
#    2721     def get_affine(self):
# -> 2722         return self._transform.get_affine()
#    2723
#    2724
#
# /usr/lib/python3.5/site-packages/matplotlib/transforms.py in get_affine(self)
#    2165                 self._affine = Affine2D(mtx)
#    2166             self._invalid = 0
# -> 2167         return self._affine
#    2168     get_affine.__doc__ = Transform.get_affine.__doc__
#    2169
#
# KeyboardInterrupt:

# %%
from moviepy.video.io.bindings import mplfig_to_npimage
import moviepy.editor as mpy

# DRAW A FIGURE WITH MATPLOTLIB

duration = 2

fig_mpl, ax = plt.subplots(1,figsize=(5,3), facecolor='white')
xx = np.linspace(-2,2,200) # the x vector
zz = lambda d: np.sinc(xx**2)+np.sin(xx+d) # the (changing) z vector
ax.set_title("Elevation in y=0")
ax.set_ylim(-1.5,2.5)
line, = ax.plot(xx, zz(0), lw=3)

# ANIMATE WITH MOVIEPY (UPDATE THE CURVE FOR EACH t). MAKE A GIF.

def make_frame_mpl(t):
    line.set_ydata( zz(2*np.pi*t/duration))  # <= Update the curve
    return mplfig_to_npimage(fig_mpl) # RGB image of the figure

animation =mpy.VideoClip(make_frame_mpl, duration=duration)
animation.write_gif("sinc_mpl.gif", fps=20)
# Out:
# [MoviePy] Building file sinc_mpl.gif with imageio
#  98%|█████████▊| 40/41 [00:00<00:00, 51.98it/s]

# %%
import gizeh
import moviepy.editor as mpy

W,H = 128,128 # width, height, in pixels
duration = 2 # duration of the clip, in seconds

def make_frame(t):
    surface = gizeh.Surface(W,H)
    radius = W*(1+ (t*(duration-t))**2 )/6
    circle = gizeh.circle(radius, xy = (W/2,H/2), fill=(1,0,0))
    circle.draw(surface)
    return surface.get_npimage()

clip = mpy.VideoClip(make_frame, duration=duration)
clip.write_gif("circle.gif",fps=15, opt="OptimizePlus", fuzz=10)
# Out:
# [MoviePy] Building file circle.gif with imageio
#  97%|█████████▋| 30/31 [00:00<00:00, 727.66it/s]

# %%
import numpy as np
import gizeh as gz
import moviepy.editor as mpy

W,H = 200,75
D = 3
r = 10 # radius of the ball
DJ, HJ = 50, 35 # distance and height of the jumps
ground = 0.75*H # y-coordinate of the ground

def make_frame(t):
    surface = gz.Surface(W,H, bg_color=(1,1,1))
    x = (-W/3)+(5*W/3)*(t/D)
    y = 20
    ball = gz.circle(r=1, fill=gradient).scale(r).translate((x,y))
    ball.draw(surface)
    return surface.get_npimage()

clip = mpy.VideoClip(make_frame, duration=D)
clip.write_gif("bouncingball.gif",fps=25, opt="OptimizePlus")
# Out:
# [MoviePy] Building file bouncingball.gif with imageio
#  99%|█████████▊| 75/76 [00:00<00:00, 639.22it/s]

# %%
Image('bouncingball.gif', format='png')

# %%
rm bouncingball.gif

# %%
funpos
# Out:
# Piecewise((-t**2 + 2*t, t < 2), (t**2 - 6*t, t >= 2))
